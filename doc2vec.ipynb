# %%
import pandas as pd
import pickle as pkl
# POT needs to be installed for the following code to work
# !pip install POT

df = pd.read_csv('data/user-ct-test-collection-02-with-query-frequencies-and-tokens.txt', sep='\t')

frequencies = pd.read_csv('data/query-frequencies-precomputed.txt', sep='\t', index_col=0)
tokens = pd.read_csv('data/query-tokens-precomputed.txt', sep='\t', index_col=0)
idf_scores = pd.read_csv('data/idf-scores-precomputed.txt', sep='\t', index_col=0)

# Dataset statistics
print('Number of rows:', df.shape[0])
print('Number of unique users:', df['AnonID'].nunique())
print('Number of unique queries:', df['Query'].nunique())
print('Query frequencies range:  [{}, {}]'.format(df['QueryFrequency'].min(), df['QueryFrequency'].max()))
print('Average query length:', df['Query'].apply(len).mean())

# User 479 queries:
df[df['AnonID'] == 479]
# Out:
# Number of rows: 3614377
# Number of unique users: 65999
# Number of unique queries: 1244495
# Query frequencies range:  [1, 98554]
# Average query length: 17.424875158291457
#      AnonID                            Query            QueryTime  ItemRank  \
# 0       479                       family guy  2006-03-01 16:01:20       NaN
# 1       479          also sprach zarathustra  2006-03-02 14:48:55       NaN
# 2       479      family guy movie references  2006-03-03 22:37:46       1.0
# 3       479  top grossing movies of all time  2006-03-03 22:42:42       1.0
# 4       479  top grossing movies of all time  2006-03-03 22:42:42       2.0
# ..      ...                              ...                  ...       ...
# 118     479                         nip tuck  2006-05-28 00:44:58       4.0
# 119     479                nip tuck season 4  2006-05-28 00:47:05       NaN
# 120     479            nip tuck season 3 dvd  2006-05-28 00:47:48       7.0
# 121     479            nip tuck season 3 dvd  2006-05-28 00:47:48       9.0
# 122     479            nip tuck season 3 dvd  2006-05-28 00:47:48       1.0
#
#                           ClickURL  QueryFrequency  \
# 0                              NaN             191
# 1                              NaN               1
# 2    http://www.familyguyfiles.com               1
# 3              http://movieweb.com               2
# 4              http://www.imdb.com               2
# ..                             ...             ...
# 118         http://www.niptuck.com              24
# 119                            NaN               4
# 120        http://en.wikipedia.org               3
# 121      http://www.dvdtimes.co.uk               3
# 122        http://www.amazon.co.uk               3
#
#                                            QueryTokens
# 0                                    ['family', 'guy']
# 1                    ['also', 'sprach', 'zarathustra']
# 2             ['family', 'guy', 'movie', 'references']
# 3    ['top', 'grossing', 'movies', 'of', 'all', 'ti...
# 4    ['top', 'grossing', 'movies', 'of', 'all', 'ti...
# ..                                                 ...
# 118                                    ['nip', 'tuck']
# 119                     ['nip', 'tuck', 'season', '4']
# 120              ['nip', 'tuck', 'season', '3', 'dvd']
# 121              ['nip', 'tuck', 'season', '3', 'dvd']
# 122              ['nip', 'tuck', 'season', '3', 'dvd']
#
# [123 rows x 7 columns]

# %%
import gensim
from gensim.models import Doc2Vec
from tqdm import tqdm  # Progress bar for training

# Tokenize queries (with tqdm progress bar)
queries = df['Query']
query_tokens = df['QueryTokens']  # list of tokenized queries

def tagged_queries(tokenized_queries):
    # Tag queries with unique IDs.
    for i, q_tokens in enumerate(tokenized_queries):
        yield gensim.models.doc2vec.TaggedDocument(q_tokens, [i])

# Train doc2vec model, on query sentences
model = Doc2Vec(vector_size=300, window=5, min_count=1, workers=4, epochs=30)

# Build vocabulary
model.build_vocab(tqdm(tagged_queries(query_tokens), desc='Building doc2vec vocabulary'))

# Train the model
model.train(tqdm(tagged_queries(query_tokens), desc='Training doc2vec model'),
            total_examples=model.corpus_count,
            epochs=model.epochs)

# Save the model
model.save('models/Doc2Vec_AOL.model')
# Out:
# Building doc2vec vocabulary: 3614377it [00:10, 360692.07it/s]
# Training doc2vec model: 3614377it [01:56, 30918.68it/s]

# %%
from nltk.tokenize import word_tokenize
from gensim.models import KeyedVectors
import numpy as np

# Query auto-completion function
def query_completion(query, completion_list, session_queries, alpha=0.6):
    N = len(session_queries)
    gamma = beta = 1/(N+1)
    omega = 0.5

    # Convert session queries to vectors
    session_queries_tokens = [word_tokenize(q) for q in session_queries]
    session_query_vectors = [model.infer_vector(q_tokens) for q_tokens in session_queries_tokens]

    # Frequency score (of each candidate query)
    frequency_score = [frequencies.loc[a, 'Frequency'] if a in frequencies.index else 0 for a in completion_list]

    # Semantic similarity score
    # Compute similarity score of each candidate with all session queries
    similarity_score = []
    for candidate_query in completion_list:  # Possible completions
        candidate_score = 0

        # Convert candidate query to vector
        candidate_tokens = word_tokenize(candidate_query)
        candidate_query_vectors = model.infer_vector(candidate_tokens)

        # Compute similarity with all session queries
        for session_vector in session_query_vectors:
            candidate_score += model.wv.cosine_similarities(candidate_query_vectors, [session_vector])[0]

        similarity_score.append(candidate_score)

    # Combined score
    combined_score = [alpha * similarity_score[i] + (1 - alpha) * frequency_score[i] for i in range(len(completion_list))]

    # Re-rank completion list
    re_ranked_list = [x for _, x in sorted(zip(combined_score, completion_list), reverse=True)]

    return re_ranked_list

# %%
# Test query auto-completion function
query = 'car'
completion_list = df[df['Query'].str.startswith(query)]['Query'].unique()  # Queries starting with 'car'
session_queries = df[(df['AnonID'] == 479) & (df['Query'].str.contains('car'))]['Query'].unique()  # Queries from user 479 containing 'car'
print(session_queries)

print("Query auto-completion for 'car':")
print(query_completion(query, completion_list, session_queries))
# Out:
# ['car decals' 'car window decals' 'car window sponsor decals'
#  'car sponsor decals' 'car brand name decals' 'bose car decal']
# Query auto-completion for 'car':
# ['cartoon network', 'cartoonnetwork.com', 'cars', 'cartoonnetwork', 'carmen electra', 'car rental', 'carmax', 'car rentals', 'careerbuilder.com', 'cars.com', 'career builder', 'cartoons', 'car buyers market', 'carmenelectra', 'carmax.com', 'careerbuilder', 'carnival cruise', 'cartoon', 'cards', 'carrie underwood', 'cartoon network.com', 'caroline kennedy', 'car', 'cartoonetwork', 'carnival cruise lines', 'carnival cruises', 'carowinds', 'care of the post operative patient', 'carlos maldonado', 'car max', 'carfax', 'cartoonnetwork toonami', 'care bears', 'car insurance', 'cartoon sex', 'carnaval ameca', 'carpenter ants', 'card games', 'car decals', 'carole king', 'cartoon dogs', 'cartoonetwork.com', 'caroline kaplan', 'caremark', 'cartoon frogs', 'carmen garcia', 'care of the post surgical patient', 'carfax.com', 'carpenter bees', 'carpal tunnel', 'career builders', 'car audio', 'cartoon.com', 'career builder.com', 'carnival cruise line', 'cars for sale', 'car search', 'carl stevens and the bible speaks', 'car parts', 'carlos mencia', 'carmella decesare', 'cardomain', 'careerbuilders.com', 'cars for sale by owner', 'car seat covers', 'carlton h kiser', 'cars of china', 'carlsbadnm.com', 'cartoon rape', 'carolyn witte', 'carolina panthers', 'cardinal richelieu political testament', 'car rims', 'car auctions', 'carnival.com', 'carpet', 'car loan', "carrabba's italian grill", 'care of the surgical patient', 'carnival', 'car graphics', 'carlsfencinginc.com', 'carol bolton furniture', 'carribean islands', 'card tricks', 'cargill milk replacer', 'cartoons swimming', 'career builders.com', 'carsdirect', 'car loans', 'carpetbaggers', 'cartoon porn', 'carpenter bee', 'car accessories', 'car shows', 'career builders. com', 'carports', 'cargo trailers in florida', 'carros de control', 'cartoonnet', 'cars pix', 'cardinal red gold shoes', 'carebears', 'carmelo sciortino', 'cartier', 'cary north carolina', 'car paint', 'cary henrie painting', 'car for sale by owner 1000.00 in illinois', 'card stock embossed with flowers', 'carry on my wayward son', 'car stereo', 'carcraft primedia.com', 'carnival cruise.com', 'cartoon pictures', 'car magnets', 'cartoon mouse', 'carsecurity', 'cartoon helicopters', 'carrentals', 'carmel clay schools', 'carpet color', 'carbohydrates with diabetes', 'carcinoid 20syndrome', 'caringbridge.com', 'car shows in new jersey', 'carmen.artsci.washington.edu', 'careerlink.com', 'cards to print save the date..wedding', 'carol pyfrom realty greenville south carolina', 'caravan tours', 'carlos santana shoes', 'caryopteris divaricata', 'cartoon people', 'carrasco', 'caribbean', 'cartoon network . com', 'carsoup.com', 'cars on rims', 'car detailing', 'carletus willis', 'carsonline.com', 'carlsbadcurrentargus.com', 'carrot cake picture', 'cartoonatwork .com', 'car soup', 'carlsbad caverns', 'cardomain.com', 'carbohydrates', 'caroldoten.edinarealty', 'car accident information form', 'caroline kennedy pictures', 'carmen electra naked', 'car kits', 'cartoline', 'cargo liner navigator', 'carpet tile', 'cartoon costumes', 'carlos torano 1916', 'carolina gamecock lamps', 'carson.army.mil', 'carla borelli', 'carved furniture', 'car top carriers', 'cardboard little leather library books', 'car rental coupons', 'cardiomyopathy', 'carla maria', 'cartoon network games', 'caring quotes', 'car sales', 'cargo shipping photos', 'cartoon of families', 'carlo rossi paisano', 'car stereos', 'car model world', 'carol wior swimsuit', 'carpal tunnel syndrome', 'carsoup', 'cary grant', 'cars .com', 'carly pope', 'carson pirie scott', 'car repair', 'car domain', 'cartoonrape', 'carlton kiser', 'carnival cruises europe 12 day itineraries', 'caringbridge', 'carmen luvana', 'caremark.com', 'carwash forsale', 'car camping maui hawaii', 'carpentry', 'cardinals.com', 'carpet serger', 'carwash equipment', 'carron simply soft patterns', 'caribwaves.com', 'car brake', 'carbs', 'carowins', 'carla arpin', 'carl mcgown', 'carolinas', 'carr', 'car care one', 'ca ...

# %%
# MRR (Mean Reciprocal Rank) evaluation
def RR(ranked_completions, ground_truth):
    """
    Reciprocal Rank (RR) for one query.
    :param ranked_completions: list of suggested completions (higher rank first)
    :param ground_truth: the correct suggestion of the query
    :return: the RR score
    """
    for i, completion in enumerate(ranked_completions):
        if completion == ground_truth:
            return 1.0 / (i + 1)
    return 0.0

def MRR(completion_lists, ground_truths):
    """
    Mean of scores for entire dataset.
    """
    total_score = 0.0
    for i, completion_list in enumerate(completion_lists):
        total_score += RR(completion_list, ground_truths[i])

    return total_score / len(completion_lists)

# %%
# Train and test datasets (arrays of query sessions, sorted by time increasing)
with open('data/train.pkl', 'rb') as f:
    train = pkl.load(f)

with open('data/test.pkl', 'rb') as f:
    test = pkl.load(f)

# Flatten train dataset
train = [query for session in train for query in session]
train = pd.DataFrame(train, columns=['Query'])

print("Train dataset size: ", len(train), "queries")
print("Test dataset size: ", len(test), "sessions and", len([query for session in test for query in session]), "queries")
print("First 10 sessions in test dataset: ")
print(test[:10])
# Session lengths counts
print("Session lengths in test dataset: ")
pd.Series([len(session) for session in test]).value_counts()
# Out:
# Train dataset size:  2709614 queries
# Test dataset size:  262547 sessions and 904763 queries
# First 10 sessions in test dataset:
# [['-', '-', '-', '-'], ['myspace.com'], ['pet sitter in newburyport ma', 'pet sitter in newburyport ma'], ['undefined'], ['shakira lyrics'], ['ebay', 'social security'], ['glutes', 'glutes', 'glutes', 'glutes', 'glutes', 'adultfriendfinder'], ['sandals vacations'], ['www.delta.com'], ['costco']]
# Session lengths in test dataset:
# 1      113402
# 2       51078
# 3       28311
# 4       17455
# 5       11957
#         ...
# 122         1
# 138         1
# 183         1
# 162         1
# 150         1
# Length: 141, dtype: int64

# %%
def get_completions(sessions, prefix_length, train_df, alpha=0.6):
    completion_lists = []
    ground_truths = []

    for session in tqdm(sessions, desc='Generating completions'):
        # Last query in the session is the query we want to complete
        query_ground_truth = session[-1]
        query_tokenized = word_tokenize(query_ground_truth)

        # Skip if the query is shorter than the prefix length
        if len(query_tokenized) < prefix_length:
            continue

        # Queries preceding the last query in the session
        previous_queries = session[:-1] if len(session) > 1 else []

        # Get prefix (part of the query that needs to be completed)
        query_prefix = ' '.join(query_tokenized[:prefix_length])

        # Get completions
        completions = train_df[train_df['Query'].str.startswith(query_prefix + " ")]['Query'].unique() # here we add a space after the word so we don't look for partial matches

        # Re-rank completions
        ranked_completions = query_completion(query_prefix, completions, previous_queries, alpha)

        completion_lists.append(ranked_completions)
        ground_truths.append(query_ground_truth)

    return completion_lists, ground_truths

def evaluate_test_set(test, prefix_length, alpha=0.6):
    completion_lists, ground_truths = get_completions(test, prefix_length, train, alpha)
    mrr = MRR(completion_lists, ground_truths)
    return mrr

# %%
# Evaluate the test set
prefix_length = 4  # query will be completed based on the first 3 words
mrr = evaluate_test_set(test, prefix_length)
print("MRR for prefix length", prefix_length, ":", mrr)
# Out:
# Generating completions:   1%|▏         | 3484/262547 [04:45<5:54:18, 12.19it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[34], line 3
#       1 # Evaluate the test set
#       2 prefix_length = 4  # query will be completed based on the first 3 words
# ----> 3 mrr = evaluate_test_set(test, prefix_length)
#       4 print("MRR for prefix length", prefix_length, ":", mrr)
#
# Cell In[33], line 32, in evaluate_test_set(test, prefix_length, alpha)
#      31 def evaluate_test_set(test, prefix_length, alpha=0.6):
# ---> 32     completion_lists, ground_truths = get_completions(test, prefix_length, train, alpha)
#      33     mrr = MRR(completion_lists, ground_truths)
#      34     return mrr
#
# Cell In[33], line 21, in get_completions(sessions, prefix_length, train_df, alpha)
#      18 query_prefix = ' '.join(query_tokenized[:prefix_length])
#      20 # Get completions
# ---> 21 completions = train_df[train_df['Query'].str.startswith(query_prefix + " ")]['Query'].unique() # here we add a space after the word so we don't look for partial matches
#      23 # Re-rank completions
#      24 ranked_completions = query_completion(query_prefix, completions, previous_queries, alpha)
#
# File ~\anaconda3\lib\site-packages\pandas\core\strings\accessor.py:125, in forbid_nonstring_types.<locals>._forbid_nonstring_types.<locals>.wrapper(self, *args, **kwargs)
#     120     msg = (
#     121         f"Cannot use .str.{func_name} with values of "
#     122         f"inferred dtype '{self._inferred_dtype}'."
#     123     )
#     124     raise TypeError(msg)
# --> 125 return func(self, *args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\strings\accessor.py:2285, in StringMethods.startswith(self, pat, na)
#    2231 @forbid_nonstring_types(["bytes"])
#    2232 def startswith(self, pat, na=None):
#    2233     """
#    2234     Test if the start of each string element matches a pattern.
#    2235
#    (...)
#    2283     dtype: bool
#    2284     """
# -> 2285     result = self._data.array._str_startswith(pat, na=na)
#    2286     return self._wrap_result(result, returns_string=False)
#
# File ~\anaconda3\lib\site-packages\pandas\core\strings\object_array.py:135, in ObjectStringArrayMixin._str_startswith(self, pat, na)
#     133 def _str_startswith(self, pat, na=None):
#     134     f = lambda x: x.startswith(pat)
# --> 135     return self._str_map(f, na_value=na, dtype=np.dtype(bool))
#
# File ~\anaconda3\lib\site-packages\pandas\core\strings\object_array.py:68, in ObjectStringArrayMixin._str_map(self, f, na_value, dtype, convert)
#      65     return np.ndarray(0, dtype=dtype)
#      67 arr = np.asarray(self, dtype=object)
# ---> 68 mask = isna(arr)
#      69 map_convert = convert and not np.all(mask)
#      70 try:
#
# File ~\anaconda3\lib\site-packages\pandas\core\dtypes\missing.py:144, in isna(obj)
#      67 def isna(obj):
#      68     """
#      69     Detect missing values for an array-like object.
#      70
#    (...)
#     142     Name: 1, dtype: bool
#     143     """
# --> 144     return _isna(obj)
#
# File ~\anaconda3\lib\site-packages\pandas\core\dtypes\missing.py:173, in _isna(obj, inf_as_na)
#     171     return False
#     172 elif isinstance(obj, (np.ndarray, ABCExtensionArray)):
# --> 173     return _isna_array(obj, inf_as_na=inf_as_na)
#     174 elif isinstance(obj, ABCIndex):
#     175     # Try to use cached isna, which also short-circuits for integer dtypes
#     176     #  and avoids materializing RangeIndex._values
#     177     if not obj._can_hold_na:
#
# File ~\anaconda3\lib\site-packages\pandas\core\dtypes\missing.py:255, in _isna_array(values, inf_as_na)
#     253         result = values.isna()  # type: ignore[assignment]
#     254 elif is_string_or_object_np_dtype(values.dtype):
# --> 255     result = _isna_string_dtype(values, inf_as_na=inf_as_na)
#     256 elif needs_i8_conversion(dtype):
#     257     # this is the NaT pattern
#     258     result = values.view("i8") == iNaT
#
# KeyboardInterrupt:

# %%
# Evaluate the test set
prefix_length = 3  # query will be completed based on the first 3 words
mrr = evaluate_test_set(test, prefix_length)
print("MRR for prefix length", prefix_length, ":", mrr)

# %%
# Evaluate the test set
prefix_length = 2  # query will be completed based on the first 2 words
mrr = evaluate_test_set(test, prefix_length)
print("MRR for prefix length", prefix_length, ":", mrr)
# Out:
# Generating completions: 100%|██████████| 200/200 [01:00<00:00,  3.32it/s]
# MRR for prefix length 2 : 0.08420522359141286

# %%
# Evaluate the test set
prefix_length = 1  # query will be completed based on the first word (VERY SLOW)
mrr = evaluate_test_set(test, prefix_length)
print("MRR for prefix length", prefix_length, ":", mrr)
